# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
# !ls ../2020J_TMA02_data/census/
# Out:
# 85043238.csv  91695374.csv  output-area-classification.csv
# 87985007.csv  93917134.csv

# %% [markdown]
# Importing the first CSV file of the census dataset.

# %%
furl = '../2020J_TMA02_data/census/85043238.csv'

df = pd.read_csv(furl, skiprows=10)
df.head()
# Out:
#   2011 super output area - middle layer   mnemonic  \
# 0                        Darlington 001  E02002559
# 1                        Darlington 002  E02002560
# 2                        Darlington 003  E02002561
# 3                        Darlington 004  E02002562
# 4                        Darlington 005  E02002563
#
#    1.1 Large employers and higher managerial and administrative occupations  \
# 0                                                2.0
# 1                                                3.0
# 2                                                2.0
# 3                                                2.0
# 4                                                0.0
#
#    1.2 Higher professional occupations  \
# 0                                 14.0
# 1                                  9.0
# 2                                  7.0
# 3                                  4.0
# 4                                 11.0
#
# ...

# %%
df.describe()
# Out:
#        1.1 Large employers and higher managerial and administrative occupations  \
# count                                        7201.000000
# mean                                            2.834884
# std                                             6.475881
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             4.000000
# max                                           414.000000
#
#        1.2 Higher professional occupations  \
# count                          7201.000000
# mean                             16.273712
# std                              15.062884
# min                               0.000000
# 25%                               8.000000
# 50%                              13.000000
# 75%                              19.000000
# max                             221.000000
#
# ...

# %%
#[SA: the project diart has been started]
